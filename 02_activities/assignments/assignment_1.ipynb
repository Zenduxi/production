# %% [markdown]
# # Working with parquet files
#
# ## Objective
#
# + In this assignment, we will use the data downloaded with the module `data_manager` to create features.
#
# (11 pts total)
#
# ## Prerequisites
#
# + This notebook assumes that price data is available to you in the environment variable `PRICE_DATA`. If you have not done so, then execute the notebook `01_materials/labs/2_data_engineering.ipynb` to create this data set.

# %% [markdown]
# + Load the environment variables using dotenv. (1 pt)

# %%
# Write your code below.
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
import dask.dataframe as dd

# %% [markdown]
# + Load the environment variable `PRICE_DATA`.
# + Use [glob](https://docs.python.org/3/library/glob.html) to find the path of all parquet files in the directory `PRICE_DATA`.
#
# (1pt)

# %%
import os
from glob import glob

# Write your code below.
print(os.getenv('PRICE_DATA'))
price_files = glob(os.path.join(os.getenv('PRICE_DATA'), '**/*.parquet'), recursive=True)
price_files
# Out:
# ../../05_src/data/prices/
# ['../../05_src/data/prices/NXC/NXC_2002/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_2002/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_2005/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_2005/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_2004/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_2004/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_2003/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_2003/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_1997/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_1997/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_1999/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_1999/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_1998/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_1998/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_1996/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_1996/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_2010/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_2010/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_2017/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_2017/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_2019/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_2019/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_2018/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_2018/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_2020/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_2020/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_2016/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_2016/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_2011/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_2011/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_2008/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_2008/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_2006/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_2006/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_2001/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_2001/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_2000/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_2000/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_2007/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_2007/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_2009/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_2009/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_1994/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_1994/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_1993/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_1993/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_1992/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_1992/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_1995/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_1995/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_2014/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_2014/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_2013/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_2013/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_2012/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_2012/part.1.parquet',
#  '../../05_src/data/prices/NXC/NXC_2015/part.0.parquet',
#  '../../05_src/data/prices/NXC/NXC_2015/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2012/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2012/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2015/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2015/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2014/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2014/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2013/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2013/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1980/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1980/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1987/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1987/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1989/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1989/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1988/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1988/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1986/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1986/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1981/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1981/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1992/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1992/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1995/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1995/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1994/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1994/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1993/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1993/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2000/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2000/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2007/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2007/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2009/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2009/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2008/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2008/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2006/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2006/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2001/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2001/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2018/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2018/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2020/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2020/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2016/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2016/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2011/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2011/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2010/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2010/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2017/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2017/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2019/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2019/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1984/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1984/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1983/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1983/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1982/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1982/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1985/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1985/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1998/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1998/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1996/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1996/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1991/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1991/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1990/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1990/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1997/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1997/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1999/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_1999/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2004/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2004/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2003/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2003/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2002/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2002/part.1.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2005/part.0.parquet',
#  '../../05_src/data/prices/BKTI/BKTI_2005/part.1.parquet',
#  '../../05_src/data/prices/APTX/APTX_2018/part.0.parquet',
#  '../../05_src/data/prices/APTX/APTX_2018/part.1.parquet',
#  '../../05_src/data/prices/APTX/APTX_2020/part.0.parquet',
#  '../../05_src/data/prices/APTX/APTX_2020/part.1.parquet',
#  '../../05_src/data/prices/APTX/APTX_2019/part.0.parquet',
#  '../../05_src/data/prices/APTX/APTX_2019/part.1.parquet',
#  '../../05_src/data/prices/AOSL/AOSL_2020/part.0.parquet',
#  '../../05_src/data/prices/AOSL/AOSL_2020/part.1.parquet',
#  '../../05_src/data/prices/AOSL/AOSL_2018/part.0.parquet',
#  '../../05_src/data/prices/AOSL/AOSL_2018/part.1.parquet',
#  '../../05_src/data/prices/AOSL/AOSL_2011/part.0.parquet',
#  '../../05_src/data/prices/AOSL/AOSL_2011/part.1.parquet',
#  '../../05_src/data/prices/AOSL/AOSL_2016/part.0.parquet',
#  '../../05_src/data/prices/AOSL/AOSL_2016/part.1.parquet',
#  '../../05_src/data/prices/AOSL/AOSL_2017/part.0.parquet',
#  '../../05_src/data/prices/AOSL/AOSL_2017/part.1.parquet',
#  '../../05_src/data/prices/AOSL/AOSL_2010/part.0.parquet',
#  '../../05_src/data/prices/AOSL/AOSL_2010/part.1.parquet',
#  '../../05_src/data/prices/AOSL/AOSL_2019/part.0.parquet',
#  '../../05_src/data/prices/AOSL/AOSL_2019/part.1.parquet',
#  '../../05_src/data/prices/AOSL/AOSL_2015/part.0.parquet',
#  '../../05_src/data/prices/AOSL/AOSL_2015/part.1.parquet',
#  '../../05_src/data/prices/AOSL/AOSL_2012/part.0.parquet',
#  '../../05_src/data/prices/AOSL/AOSL_2012/part.1.parquet',
#  '../../05_src/data/prices/AOSL/AOSL_2013/part.0.parquet',
#  '../../05_src/data/prices/AOSL/AOSL_2013/part.1.parquet',
#  '../../05_src/data/prices/AOSL/AOSL_2014/part.0.parquet',
#  '../../05_src/data/prices/AOSL/AOSL_2014/part.1.parquet',
#  '../../05_src/data/prices/INFY/INFY_2010/part.0.parquet',
#  '../../05_src/data/prices/INFY/INFY_2010/part.1.parquet',
#  '../../05_src/data/prices/INFY/INFY_2017/part.0.parquet',
#  '../../05_src/data/prices/INFY/INFY_2017/part.1.parquet',
#  '../../05_src/data/prices/INFY/INFY_2019/part.0.parquet',
#  '../../05_src/data/prices/INFY/INFY_2019/part.1.parquet',
#  '../../05_src/data/prices/INFY/INFY_2018/part.0.parquet',
#  '../../05_src/data/prices/INFY/INFY_2018/part.1.parquet',
#  '../../05_src/data/prices/INFY/INFY_2020/part.0.parquet',
#  '../../05_src/data/prices/INFY/INFY_2020/part.1.parquet',
#  '../../05_src/data/prices/INFY/INFY_2016/part.0.parquet',
#  '../../05_src/data/prices/INFY/INFY_2016/part.1.parquet',
#  '../../05_src/data/prices/INFY/INFY_2011/part.0.parquet',
#  '../../05_src/data/prices/INFY/INFY_2011/part.1.parquet',
#  '../../05_src/data/prices/INFY/INFY_2002/part.0.parquet',
#  '../../05_src/data/prices/INFY/INFY_2002/part.1.parquet',
#  '../../05_src/data/prices/INFY/INFY_2005/part.0.parquet',
#  '../../05_src/data/prices/INFY/INFY_2005/part.1.parquet',
#  '../../05_src/data/prices/INFY/INFY_2004/part.0.parquet',
#  '../../05_src/data/prices/INFY/INFY_2004/part.1.parquet',
#  '../../05_src/data/prices/INFY/INFY_2003/part.0.parquet',
#  '../../05_src/data/prices/INFY/INFY_2003/part.1.parquet',
#  '../../05_src/data/prices/INFY/INFY_1999/part.0.parquet',
#  '../../05_src/data/prices/INFY/INFY_1999/part.1.parquet',
#  '../../05_src/data/prices/INFY/INFY_2014/part.0.parquet',
#  '../../05_src/data/prices/INFY/INFY_2014/part.1.parquet',
#  '../../05_src/data/prices/INFY/INFY_2013/part.0.parquet',
#  '../../05_src/data/prices/INFY/INFY_2013/part.1.parquet',
#  '../../05_src/data/prices/INFY/INFY_2012/part.0.parquet',
#  '../../05_src/data/prices/INFY/INFY_2012/part.1.parquet',
#  '../../05_src/data/prices/INFY/INFY_2015/part.0.parquet',
#  '../../05_src/data/prices/INFY/INFY_2015/part.1.parquet',
#  '../../05_src/data/prices/INFY/INFY_2008/part.0.parquet',
#  '../../05_src/data/prices/INFY/INFY_2008/part.1.parquet',
#  '../../05_src/data/prices/INFY/INFY_2006/part.0.parquet',
#  '../../05_src/data/prices/INFY/INFY_
parquet',
#  '../../05_src/data/prices/TNAV/TNAV_2019/part.0.parquet',
#  '../../05_src/data/prices/TNAV/TNAV_2019/part.1.parquet',
#  '../../05_src/data/prices/MDRRP/MDRRP_2020/part.0.parquet',
#  '../../05_src/data/prices/MDRRP/MDRRP_2020/part.1.parquet',
#  '../../05_src/data/prices/ETM/ETM_2014/part.0.parquet',
#  '../../05_src/data/prices/ETM/ETM_2014/part.1.parquet',
#  '../../05_src/data/prices/ETM/ETM_2013/part.0.parquet',
#  '../../05_src/data/prices/ETM/ETM_2013/part.1.parquet',
#  '../../05_src/data/prices/ETM/ETM_2012/part.0.parquet',
#  '../../05_src/data/prices/ETM/ETM_2012/part.1.parquet',
#  '../../05_src/data/prices/ETM/ETM_2015/part.0.parquet',
#  '../../05_src/data/prices/ETM/ETM_2015/part.1.parquet',
#  '../../05_src/data/prices/ETM/ETM_2006/part.0.parquet',
#  '../../05_src/data/prices/ETM/ETM_2006/part.1.parquet',
#  '../../05_src/data/prices/ETM/ETM_2001/part.0.parquet',
#  '../../05_src/data/prices/ETM/ETM_2001/part.1.parquet',
#  '../../05_src/data/prices/ETM/ETM_2008/part.0.parquet',
#  '../../05_src/data/prices/ETM/ETM_2008/part.1.parquet',
#  '../../05_src/data/prices/ETM/ETM_2009/part.0.parquet',
#  '../../05_src/data/prices/ETM/ETM_2009/part.1.parquet',
#  '../../05_src/data/prices/ETM/ETM_2000/part.0.parquet',
#  '../../05_src/data/prices/ETM/ETM_2000/part.1.parquet',
#  '../../05_src/data/prices/ETM/ETM_2007/part.0.parquet',
#  '../../05_src/data/prices/ETM/ETM_2007/part.1.parquet',
#  '../../05_src/data/prices/ETM/ETM_2019/part.0.parquet',
#  '../../05_src/data/prices/ETM/ETM_2019/part.1.parquet',
#  '../../05_src/data/prices/ETM/ETM_2010/part.0.parquet',
#  '../../05_src/data/prices/ETM/ETM_2010/part.1.parquet',
#  '../../05_src/data/prices/ETM/ETM_2017/part.0.parquet',
#  '../../05_src/data/prices/ETM/ETM_2017/part.1.parquet',
#  '../../05_src/data/prices/ETM/ETM_2016/part.0.parquet',
#  '../../05_src/data/prices/ETM/ETM_2016/part.1.parquet',
#  '../../05_src/data/prices/ETM/ETM_2011/part.0.parquet',
#  '../../05_src/data/prices/ETM/ETM_2011/part.1.parquet',
#  '../../05_src/data/prices/ETM/ETM_2018/part.0.parquet',
#  '../../05_src/data/prices/ETM/ETM_2018/part.1.parquet',
#  '../../05_src/data/prices/ETM/ETM_2020/part.0.parquet',
#  '../../05_src/data/prices/ETM/ETM_2020/part.1.parquet',
#  '../../05_src/data/prices/ETM/ETM_1999/part.0.parquet',
#  '../../05_src/data/prices/ETM/ETM_1999/part.1.parquet',
#  '../../05_src/data/prices/ETM/ETM_2002/part.0.parquet',
#  '../../05_src/data/prices/ETM/ETM_2002/part.1.parquet',
#  '../../05_src/data/prices/ETM/ETM_2005/part.0.parquet',
#  '../../05_src/data/prices/ETM/ETM_2005/part.1.parquet',
#  '../../05_src/data/prices/ETM/ETM_2004/part.0.parquet',
#  '../../05_src/data/prices/ETM/ETM_2004/part.1.parquet',
#  '../../05_src/data/prices/ETM/ETM_2003/part.0.parquet',
#  '../../05_src/data/prices/ETM/ETM_2003/part.1.parquet',
#  '../../05_src/data/prices/ATHM/ATHM_2013/part.0.parquet',
#  '../../05_src/data/prices/ATHM/ATHM_2013/part.1.parquet',
#  '../../05_src/data/prices/ATHM/ATHM_2014/part.0.parquet',
#  '../../05_src/data/prices/ATHM/ATHM_2014/part.1.parquet',
#  '../../05_src/data/prices/ATHM/ATHM_2015/part.0.parquet',
#  '../../05_src/data/prices/ATHM/ATHM_2015/part.1.parquet',
#  '../../05_src/data/prices/ATHM/ATHM_2019/part.0.parquet',
#  '../../05_src/data/prices/ATHM/ATHM_2019/part.1.parquet',
#  '../../05_src/data/prices/ATHM/ATHM_2017/part.0.parquet',
#  '../../05_src/data/prices/ATHM/ATHM_2017/part.1.parquet',
#  '../../05_src/data/prices/ATHM/ATHM_2016/part.0.parquet',
#  '../../05_src/data/prices/ATHM/ATHM_2016/part.1.parquet',
#  '../../05_src/data/prices/ATHM/ATHM_2020/part.0.parquet',
#  '../../05_src/data/prices/ATHM/ATHM_2020/part.1.parquet',
#  '../../05_src/data/prices/ATHM/ATHM_2018/part.0.parquet',
#  '../../05_src/data/prices/ATHM/ATHM_2018/part.1.parquet',
#  '../../05_src/data/prices/VLRS/VLRS_2014/part.0.parquet',
#  '../../05_src/data/prices/VLRS/VLRS_2014/part.1.parquet',
#  '../../05_src/data/prices/VLRS/VLRS_2013/part.0.parquet',
#  '../../05_src/data/prices/VLRS/VLRS_2013/part.1.parquet',
#  '../../05_src/data/prices/VLRS/VLRS_2015/part.0.parquet',
#  '../../05_src/data/prices/VLRS/VLRS_2015/part.1.parquet',
#  '../../05_src/data/prices/VLRS/VLRS_2019/part.0.parquet',
#  '../../05_src/data/prices/VLRS/VLRS_2019/part.1.parquet',
#  '../../05_src/data/prices/VLRS/VLRS_2017/part.0.parquet',
#  '../../05_src/data/prices/VLRS/VLRS_2017/part.1.parquet',
#  '../../05_src/data/prices/VLRS/VLRS_2016/part.0.parquet',
#  '../../05_src/data/prices/VLRS/VLRS_2016/part.1.parquet',
#  '../../05_src/data/prices/VLRS/VLRS_2018/part.0.parquet',
#  '../../05_src/data/prices/VLRS/VLRS_2018/part.1.parquet',
#  '../../05_src/data/prices/VLRS/VLRS_2020/part.0.parquet',
#  '../../05_src/data/prices/VLRS/VLRS_2020/part.1.parquet',
#  '../../05_src/data/prices/PSCD/PSCD_2012/part.0.parquet',
#  '../../05_src/data/prices/PSCD/PSCD_2012/part.1.parquet',
#  '../../05_src/data/prices/PSCD/PSCD_2015/part.0.parquet',
#  '../../05_src/data/prices/PSCD/PSCD_2015/part.1.parquet',
#  '../../05_src/data/prices/PSCD/PSCD_2014/part.0.parquet',
#  '../../05_src/data/prices/PSCD/PSCD_2014/part.1.parquet',
#  '../../05_src/data/prices/PSCD/PSCD_2013/part.0.parquet',
#  '../../05_src/data/prices/PSCD/PSCD_2013/part.1.parquet',
#  '../../05_src/data/prices/PSCD/PSCD_2016/part.0.parquet',
#  '../../05_src/data/prices/PSCD/PSCD_2016/part.1.parquet',
#  '../../05_src/data/prices/PSCD/PSCD_2011/part.0.parquet',
#  '../../05_src/data/prices/PSCD/PSCD_2011/part.1.parquet',
#  '../../05_src/data/prices/PSCD/PSCD_2018/part.0.parquet',
#  '../../05_src/data/prices/PSCD/PSCD_2018/part.1.parquet',
#  '../../05_src/data/prices/PSCD/PSCD_2020/part.0.parquet',
#  '../../05_src/data/prices/PSCD/PSCD_2020/part.1.parquet',
#  '../../05_src/data/prices/PSCD/PSCD_2019/part.0.parquet',
#  '../../05_src/data/prices/PSCD/PSCD_2019/part.1.parquet',
#  '../../05_src/data/prices/PSCD/PSCD_2010/part.0.parquet',
#  '../../05_src/data/prices/PSCD/PSCD_2010/part.1.parquet',
#  '../../05_src/data/prices/PSCD/PSCD_2017/part.0.parquet',
#  '../../05_src/data/prices/PSCD/PSCD_2017/part.1.parquet',
#  '../../05_src/data/prices/RILYP/RILYP_2020/part.0.parquet',
#  '../../05_src/data/prices/RILYP/RILYP_2020/part.1.parquet',
#  '../../05_src/data/prices/TMF/TMF_2018/part.0.parquet',
#  '../../05_src/data/prices/TMF/TMF_2018/part.1.parquet',
#  '../../05_src/data/prices/TMF/TMF_2020/part.0.parquet',
#  '../../05_src/data/prices/TMF/TMF_2020/part.1.parquet',
#  '../../05_src/data/prices/TMF/TMF_2016/part.0.parquet',
#  '../../05_src/data/prices/TMF/TMF_2016/part.1.parquet',
#  '../../05_src/data/prices/TMF/TMF_2011/part.0.parquet',
#  '../../05_src/data/prices/TMF/TMF_2011/part.1.parquet',
#  '../../05_src/data/prices/TMF/TMF_2010/part.0.parquet',
#  '../../05_src/data/prices/TMF/TMF_2010/part.1.parquet',
#  '../../05_src/data/prices/TMF/TMF_2017/part.0.parquet',
#  '../../05_src/data/prices/TMF/TMF_2017/part.1.parquet',
#  '../../05_src/data/prices/TMF/TMF_2019/part.0.parquet',
#  '../../05_src/data/prices/TMF/TMF_2019/part.1.parquet',
#  '../../05_src/data/prices/TMF/TMF_2012/part.0.parquet',
#  '../../05_src/data/prices/TMF/TMF_2012/part.1.parquet',
#  '../../05_src/data/prices/TMF/TMF_2015/part.0.parquet',
#  '../../05_src/data/prices/TMF/TMF_2015/part.1.parquet',
#  '../../05_src/data/prices/TMF/TMF_2014/part.0.parquet',
#  '../../05_src/data/prices/TMF/TMF_2014/part.1.parquet',
#  '../../05_src/data/prices/TMF/TMF_2013/part.0.parquet',
#  '../../05_src/data/prices/TMF/TMF_2013/part.1.parquet',
#  '../../05_src/data/prices/TMF/TMF_2009/part.0.parquet',
#  '../../05_src/data/prices/TMF/TMF_2009/part.1.parquet',
#  '../../05_src/data/prices/GLG/GLG_2015/part.0.parquet',
#  '../../05_src/data/prices/GLG/GLG_2015/part.1.parquet',
#  '../../05_src/data/prices/GLG/GLG_2012/part.0.parquet',
#  '../../05_src/data/prices/GLG/GLG_2012/part.1.parquet',
#  '../../05_src/data/prices/GLG/GLG_2013/part.0.parquet',
#  '../../05_src/data/prices/GLG/GLG_2013/part.1.parquet',
#  '../../05_src/data/prices/GLG/GLG_2014/part.0.parquet',
#  '../../05_src/data/prices/GLG/GLG_2014/part.1.parquet',
#  '../../05_src/data/prices/GLG/GLG_2020/part.0.parquet',
#  ...]

# %% [markdown]
# For each ticker and using Dask, do the following:
#
# + Add lags for variables Close and Adj_Close.
# + Add returns based on Close:
#
#     - `returns`: (Close / Close_lag_1) - 1
#
# + Add the following range:
#
#     - `hi_lo_range`: this is the day's High minus Low.
#
# + Assign the result to `dd_feat`.
#
# (4 pt)

# %%
# Write your code below.
dd_pp = dd.read_parquet(price_files,set_index='ticker')

dd_shift = dd_pp.groupby('ticker',group_keys=False).apply(lambda x: x.assign(Close_lag_1 = x['Close'].shift(1),
                                                                             Adj_Close_lag = x['Adj Close'].shift(1)))

dd_feat = dd_shift.assign(returns = lambda x: x['Close']/x['Close_lag_1']-1, hi_lo_range = lambda x: x['High'] - x['Low'])
dd_feat
# Out:
# /var/folders/xd/827g3ndd0kg_81hlxd5mbp2m0000gn/T/ipykernel_69607/4090045487.py:4: UserWarning: `meta` is not specified, inferred from partial data.
# Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#
#   dd_shift = dd_pp.groupby('ticker',group_keys=False).apply(lambda x: x.assign(Close_lag_1 = x['Close'].shift(1),
# Dask DataFrame Structure:
#                             Date     Open     High      Low    Close Adj Close   Volume  source  ticker   Year Close_lag_1 Adj_Close_lag  returns hi_lo_range
# npartitions=2893
#                   datetime64[ns]  float64  float64  float64  float64   float64  float64  string  string  int32     float64       float64  float64     float64
#                              ...      ...      ...      ...      ...       ...      ...     ...     ...    ...         ...           ...      ...         ...
# ...                          ...      ...      ...      ...      ...       ...      ...     ...     ...    ...         ...           ...      ...         ...
#                              ...      ...      ...      ...      ...       ...      ...     ...     ...    ...         ...           ...      ...         ...
#                              ...      ...      ...      ...      ...       ...      ...     ...     ...    ...         ...           ...      ...         ...
# Dask Name: assign, 13 expressions
# Expr=Assign(frame=Assign(frame=Assign(frame=Assign(frame=GroupByApply(frame=ReadParquetFSSpec(e9193f3), observed=False, group_keys=False, func=<function <lambda> at 0x14c57a840>, meta=<no_default>, args=(), kwargs={})))))

# %% [markdown]
# + Convert the Dask data frame to a pandas data frame.
# + Add a new feature containing the moving average of `returns` using a window of 10 days. There are several ways to solve this task, a simple one uses `.rolling(10).mean()`.
#
# (3 pt)

# %%
# Write your code below.
pd_pf = dd_feat.compute()

# To avoid repeating the above relatively expensive computing when I tested the following code, 
# I moved the code to the next cell.

# %%
# Zhen's notes: the dataset has been grouped by 'ticker' and by observation, within each ticker group, the data is sorted ascending by Date.
# To ensure sorting by date ascending so that moving average is meaningful, I use the following sort_values() function.
df_sorted = pd_pf.groupby('ticker').apply(lambda x: x.sort_values('Date'))
df_sorted
pd_pf['moving_avg_returns'] = pd_pf['returns'].rolling(10).mean()
pd_pf
# Out:
# /var/folders/xd/827g3ndd0kg_81hlxd5mbp2m0000gn/T/ipykernel_69607/1436193359.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_sorted = pd_pf.groupby('ticker').apply(lambda x: x.sort_values('Date'))
#              Date  Open   High   Low  Close  Adj Close      Volume    source  \
# 4067   2020-02-19  5.18  5.240  5.08   5.18       5.18    121500.0  ALDX.csv
# 4068   2020-02-20  5.17  5.230  5.05   5.06       5.06    161500.0  ALDX.csv
# 4069   2020-02-21  5.07  5.100  5.03   5.05       5.05    119700.0  ALDX.csv
# 4070   2020-02-24  5.10  5.117  4.82   4.84       4.84    462600.0  ALDX.csv
# 4071   2020-02-25  4.84  4.898  4.40   4.50       4.50    341700.0  ALDX.csv
# ...           ...   ...    ...   ...    ...        ...         ...       ...
# 229073 2015-06-26  1.62  1.690  1.55   1.64       1.64  10886800.0   UEC.csv
# 229074 2015-06-29  1.67  1.690  1.47   1.54       1.54   3615400.0   UEC.csv
# 229075 2015-06-30  1.55  1.610  1.54   1.59       1.59   1341400.0   UEC.csv
# 229076 2015-07-01  1.62  1.690  1.45   1.48       1.48   1910200.0   UEC.csv
# 229077 2015-07-02  1.46  1.480  1.40   1.41       1.41   2168000.0   UEC.csv
#
#        ticker  Year  Close_lag_1  Adj_Close_lag   returns  hi_lo_range  \
# 4067     ALDX  2020          NaN            NaN       NaN        0.160
# 4068     ALDX  2020         5.18           5.18 -0.023166        0.180
# 4069     ALDX  2020         5.06           5.06 -0.001976        0.070
# 4070     ALDX  2020         5.05           5.05 -0.041584        0.297
# 4071     ALDX  2020         4.84           4.84 -0.070248        0.498
# ...       ...   ...          ...            ...       ...          ...
# 229073    UEC  2015         1.60           1.60  0.025000        0.140
# 229074    UEC  2015         1.64           1.64 -0.060976        0.220
# 229075    UEC  2015         1.54           1.54  0.032468        0.070
# 229076    UEC  2015         1.59           1.59 -0.069182        0.240
# 229077    UEC  2015         1.48           1.48 -0.047297        0.080
#
#         moving_avg_returns
# 4067                   NaN
# 4068                   NaN
# 4069                   NaN
# 4070                   NaN
# 4071                   NaN
# ...                    ...
# 229073           -0.050529
# 229074           -0.053167
# 229075           -0.048486
# 229076           -0.049950
# 229077           -0.047757
#
# [332152 rows x 15 columns]

# %%
# Zhen's test
pd_pf.info()
type(pd_pf)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 332152 entries, 4067 to 229077
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Date                332152 non-null  datetime64[ns]
#  1   Open                332139 non-null  float64
#  2   High                332139 non-null  float64
#  3   Low                 332139 non-null  float64
#  4   Close               332139 non-null  float64
#  5   Adj Close           332139 non-null  float64
#  6   Volume              332139 non-null  float64
#  7   source              332152 non-null  string
#  8   ticker              332152 non-null  string
#  9   Year                332152 non-null  int32
#  10  Close_lag_1         332050 non-null  float64
#  11  Adj_Close_lag       332050 non-null  float64
#  12  returns             332040 non-null  float64
#  13  hi_lo_range         332139 non-null  float64
#  14  moving_avg_returns  331162 non-null  float64
# dtypes: datetime64[ns](1), float64(11), int32(1), string(2)
# memory usage: 42.7 MB
# pandas.core.frame.DataFrame

# %% [markdown]
# Please comment:
#
# + Was it necessary to convert to pandas to calculate the moving average return?
# + Would it have been better to do it in Dask? Why?
#
# (1 pt)

# %% [markdown]
# ## Criteria
#
# The [rubric](./assignment_1_rubric_clean.xlsx) contains the criteria for grading.

# %% [markdown]
# ## Submission Information
#
# 🚨 **Please review our [Assignment Submission Guide](https://github.com/UofT-DSI/onboarding/blob/main/onboarding_documents/submissions.md)** 🚨 for detailed instructions on how to format, branch, and submit your work. Following these guidelines is crucial for your submissions to be evaluated correctly.
#
# ### Submission Parameters:
# * Submission Due Date: `HH:MM AM/PM - DD/MM/YYYY`
# * The branch name for your repo should be: `assignment-1`
# * What to submit for this assignment:
#     * This Jupyter Notebook (assignment_1.ipynb) should be populated and should be the only change in your pull request.
# * What the pull request link should look like for this assignment: `https://github.com/<your_github_username>/production/pull/<pr_id>`
#     * Open a private window in your browser. Copy and paste the link to your pull request into the address bar. Make sure you can see your pull request properly. This helps the technical facilitator and learning support staff review your submission easily.
#
# Checklist:
# - [ ] Created a branch with the correct naming convention.
# - [ ] Ensured that the repository is public.
# - [ ] Reviewed the PR description guidelines and adhered to them.
# - [ ] Verify that the link is accessible in a private browser window.
#
# If you encounter any difficulties or have questions, please don't hesitate to reach out to our team via our Slack at `#cohort-3-help`. Our Technical Facilitators and Learning Support staff are here to help you navigate any challenges.
